# %%
import pandas as pd 
s=pd.read_csv('C:/Users/user/Downloads/dataset.csv',index_col=0)
s.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# IT IS ABOUT THE RECORD OF SURVIVORS WHO HAVE SURVIVED THE TITANIC SHIP CRASH IN 1912

# %%
import pandas as pd 
s=pd.read_csv('C:/Users/user/Downloads/dataset.csv',index_col=0)
s.fillna(20)
# Out:
#     Survived  Pclass                                               Name  \
# No
# 1         No       3                            Braund, Mr. Owen Harris
# 2        Yes       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3        Yes       3                             Heikkinen, Miss. Laina
# 4        Yes       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5         No       3                           Allen, Mr. William Henry
# ..       ...     ...                                                ...
# 887       No       2                              Montvila, Rev. Juozas
# 888      Yes       1                       Graham, Miss. Margaret Edith
# 889       No       3           Johnston, Miss. Catherine Helen "Carrie"
# 890      Yes       1                              Behr, Mr. Karl Howell
# 891       No       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# No
# ...

# %%
import pandas as pd 
s=pd.read_csv('C:/Users/user/Downloads/dataset.csv',index_col=0)
s.rename_axis("PassengerID", axis='rows')
# Out:
#             Survived  Pclass  \
# PassengerID
# 1                 No       3
# 2                Yes       1
# 3                Yes       3
# 4                Yes       1
# 5                 No       3
# ...              ...     ...
# 887               No       2
# 888              Yes       1
# 889               No       3
# 890              Yes       1
# 891               No       3
#
#                                                           Name     Sex   Age  \
# PassengerID
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
s=pd.read_csv('C:/Users/user/Downloads/dataset.csv',index_col=0)
x=s.Age 
y=s.Fare
plt.scatter(x,y)
plt.show()

# %% [markdown]
# THIS IS A GRAPH WHICH CONTAINS X AXIS AS AGE OF THE SURVIVORS AND Y AXIS AS FARE AND I HAVE CREATED A SCATTER GRAPH TO GET A CLEAR IDEA OF THE DATA
